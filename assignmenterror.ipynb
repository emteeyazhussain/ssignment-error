# %%
Q2.def print_exception_hierarchy(exc_class, indent=0):
    print(" " * indent, exc_class.__name__)
    for subclass in exc_class.__subclasses__():
        print_exception_hierarchy(subclass, indent+4)

print_exception_hierarchy(BaseException)
# Out:
#  BaseException
#      Exception
#          TypeError
#              FloatOperation
#              MultipartConversionError
#          StopAsyncIteration
#          StopIteration
#          ImportError
#              ModuleNotFoundError
#              ZipImportError
#          OSError
#              ConnectionError
#                  BrokenPipeError
#                  ConnectionAbortedError
#                  ConnectionRefusedError
#                  ConnectionResetError
#                      RemoteDisconnected
#              BlockingIOError
#              ChildProcessError
#              FileExistsError
#              FileNotFoundError
#              IsADirectoryError
#              NotADirectoryError
#              InterruptedError
#                  InterruptedSystemCall
#              PermissionError
#              ProcessLookupError
#              TimeoutError
#              UnsupportedOperation
#              itimer_error
#              herror
#              gaierror
# ...

# %%
Q2.def print_exception_hierarchy(exc_class, indent=0):
    print(" " * indent, exc_class.__name__)
    for subclass in exc_class.__subclasses__():
        print_exception_hierarchy(subclass, indent+4)

print_exception_hierarchy(BaseException)
# Out:
#  BaseException
#      Exception
#          TypeError
#              FloatOperation
#              MultipartConversionError
#          StopAsyncIteration
#          StopIteration
#          ImportError
#              ModuleNotFoundError
#              ZipImportError
#          OSError
#              ConnectionError
#                  BrokenPipeError
#                  ConnectionAbortedError
#                  ConnectionRefusedError
#                  ConnectionResetError
#                      RemoteDisconnected
#              BlockingIOError
#              ChildProcessError
#              FileExistsError
#              FileNotFoundError
#              IsADirectoryError
#              NotADirectoryError
#              InterruptedError
#                  InterruptedSystemCall
#              PermissionError
#              ProcessLookupError
#              TimeoutError
#              UnsupportedOperation
#              itimer_error
#              herror
#              gaierror
# ...

# %%
#Q3. The ArithmeticError class in Python is the base class for errors that occur during arithmetic operations. Some of the errors 
# that are defined as subclasses of ArithmeticError include FloatingPointError,OverflowError, and ZeroDivisionError.

# Here are two examples of errors that are defined in the ArithmeticError class:

# FloatingPointError: This error occurs when a floating-point calculation results in an exception. For example, consider the
# following code:
x = 1.0
y = 0.0
z = x / y
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 10
#       8 x = 1.0
#       9 y = 0.0
# ---> 10 z = x / y
#
# ZeroDivisionError: float division by zero

# %%
x = 1.0
y = 0.0
try:
    z = x / y
except ArithmeticError:
    print("ArithmeticError occurred")
# Out:
# ArithmeticError occurred

# %%
# OverflowError: This error occurs when a numeric calculation exceeds the maximum representable value for a numeric type.
# For example, consider the following code:

# %%
import sys
x = sys.maxsize
y = 2
z = x * y

# %%
import sys
x = sys.maxsize
y = 2
try:
    z = x * y
except ArithmeticError:
    print("ArithmeticError occurred")

# %%
# Q4 The LookupError class in Python is the base class for errors that occur when a key or index is not found in a sequence or mapping.
# Some of the errors that are defined as subclasses of LookupError include IndexError and KeyError.

# Here are two examples of errors that are defined in the LookupError class:

# KeyError: This error occurs when a key is not found in a dictionary or other mapping type. For example, consider the following
# code:
d = {'a': 1, 'b': 2, 'c': 3}
print(d['d'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 9
#       1 # The LookupError class in Python is the base class for errors that occur when a key or index is not found in a sequence or mapping.
#       2 # Some of the errors that are defined as subclasses of LookupError include IndexError and KeyError.
#       3
#    (...)
#       6 # KeyError: This error occurs when a key is not found in a dictionary or other mapping type. For example, consider the following
#       7 # code:
#       8 d = {'a': 1, 'b': 2, 'c': 3}
# ----> 9 print(d['d'])
#
# KeyError: 'd'

# %%
d = {'a': 1, 'b': 2, 'c': 3}
try:
    print(d['d'])
except KeyError:
    print("KeyError occurred")
# Out:
# KeyError occurred

# %%
# IndexError: This error occurs when an index is out of range for a sequence (e.g. a list or tuple). For example, consider 
# the following
# code:
l = [1, 2, 3]
print(l[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 5
#       1 # IndexError: This error occurs when an index is out of range for a sequence (e.g. a list or tuple). For example, consider
#       2 # the following
#       3 # code:
#       4 l = [1, 2, 3]
# ----> 5 print(l[3])
#
# IndexError: list index out of range

# %%
l = [1, 2, 3]
try:
    print(l[3])
    
except IndexError:
        print("IndexError occurred")
# Out:
# IndexError occurred

# %%
# Q5:# In Python, ImportError is an exception that is raised when a module or package cannot be imported. This can occur for a variety 
# of reasons, such as if the module or package does not exist, if it is not installed, or if there is an error in the module or 
# package's code.

# ImportError is a built-in exception class in Python that is raised when an import statement cannot locate the module to be 
# imported or when there is an issue while importing a module.

# For example, consider the following code:
try:
    import some_module
except ImportError:
    print("ImportError occurred")

# %%
# Q6;

"""Here are some best practices for exception handling in Python:

Catch only the exceptions you expect: It's important to be specific about the exceptions you catch, rather than using a broad 
except clause that catches all exceptions. This helps ensure that you're not masking other errors that you didn't anticipate.

Handle exceptions where they occur: Try to handle exceptions at the point where they occur, rather than letting them propagate up 
the call stack. This can make it easier to trace and debug errors.

Provide helpful error messages: When an exception is caught, provide an informative error message that explains what went wrong
and how to resolve the issue. This can help users and developers understand what's happening and how to fix the problem.

Use finally blocks to clean up resources: If you're working with resources that need to be closed (such as files or network 
connections), use a finally block to ensure that the resource is properly closed even if an exception is raised.

Don't use exceptions for control flow: Exceptions are designed to handle exceptional cases, not to control the flow of a program.
Avoid using exceptions as a way to control program flow, as this can make code harder to read and debug.

Use specific exception types: Use specific exception types to make your code more readable and maintainable. This also helps
avoid masking other errors that you didn't anticipate.
"""
# Out:
# "Here are some best practices for exception handling in Python:\n\nCatch only the exceptions you expect: It's important to be specific about the exceptions you catch, rather than using a broad \nexcept clause that catches all exceptions. This helps ensure that you're not masking other errors that you didn't anticipate.\n\nHandle exceptions where they occur: Try to handle exceptions at the point where they occur, rather than letting them propagate up \nthe call stack. This can make it easier to trace and debug errors.\n\nProvide helpful error messages: When an exception is caught, provide an informative error message that explains what went wrong\nand how to resolve the issue. This can help users and developers understand what's happening and how to fix the problem.\n\nUse finally blocks to clean up resources: If you're working with resources that need to be closed (such as files or network \nconnections), use a finally block to ensure that the resource is properly closed even if an e
# ...

# %%
# Q1.


# Q1.In Python, an exception is a runtime error that occurs when the code encounters an unexpected situation or an error.
# In some cases, the built-in exceptions provided by Python may not be sufficient to represent the specific type of error that your
# program may encounter. In such situations, you may need to create a custom exception that can be raised and handled in a manner 
# specific to your program's requirements.

# When you create a custom exception in Python, it is recommended to derive it from the base Exception class. This is because the
# Exception class provides a set of methods that can be used to handle and manipulate exceptions, such as str(), args(), with_traceback(), etc. By inheriting from the Exception class, your custom exception class can leverage these methods and also get the benefits of the existing exception handling mechanisms provided by Python.

# For example, if you create a custom exception that inherits from the Exception class, you can catch it in a try...except block
# just like any other exception. Additionally, you can also catch it using a more general exception such as except Exception, which will catch all the exceptions, including your custom exception.

# Here is an example of creating a custom exception that inherits from the Exception class:

# python  Copy code:
    
# class MyCustomException(Exception):
     # pass
    
# In summary, by using the Exception class as the base class for your custom exception, you can take advantage of the existing 
# exception handling mechanisms provided by Python and provide a more specific and meaningful error message for your program.
